# %%
import brightway2 as bw
from brightway2 import *
import time
import os
import numpy as np
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# File ~\Anaconda3\envs\bw2\lib\site-packages\peewee.py:3237, in Database.execute_sql(self, sql, params, commit)
#    3236 try:
# -> 3237     cursor.execute(sql, params or ())
#    3238 except Exception:
#
# DatabaseError: file is not a database
#
# During handling of the above exception, another exception occurred:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import brightway2 as bw
#       2 from brightway2 import *
#       3 import time
#
# File ~\Anaconda3\envs\bw2\lib\site-packages\brightway2\__init__.py:2
#       1 # -*- coding: utf-8 -*
# ----> 2 from bw2data import *
#       3 from bw2calc import *
#       4 from bw2io import *
#
# File ~\Anaconda3\envs\bw2\lib\site-packages\bw2data\__init__.py:33
#      29 __version__ = (3, 6, 5)
#      32 from .configuration import config
# ---> 33 from .project import projects
#      34 from .utils import set_data_dir
#      35 from .meta import (
#      36     dynamic_calculation_setups,
#      37     calculation_setups,
#    (...)
#      44     weightings,
#      45 )
#
# File ~\Anaconda3\envs\bw2\lib\site-packages\bw2data\project.py:351
#     347         self.set_current(_current)
#     348         return data
# --> 351 projects = ProjectManager()
#     354 @wrapt.decorator
#     355 def writable_project(wrapped, instance, args, kwargs):
#     356     if projects.read_only:
#
# File ~\Anaconda3\envs\bw2\lib\site-packages\bw2data\project.py:73, in ProjectManager.__init__(self)
#      71 self._base_data_dir, self._base_logs_dir = self._get_base_directories()
#      72 self._create_base_directories()
# ---> 73 self.db = SubstitutableDatabase(
#      74     os.path.join(self._base_data_dir, "projects.db"),
#      75     [ProjectDataset]
#      76 )
#      77 self.set_current("default", update=False)
#
# File ~\Anaconda3\envs\bw2\lib\site-packages\bw2data\sqlite.py:27, in SubstitutableDatabase.__init__(self, filepath, tables)
#      25 self._filepath = filepath
#      26 self._tables = tables
# ---> 27 self._database = self._create_database()
#
# File ~\Anaconda3\envs\bw2\lib\site-packages\bw2data\sqlite.py:34, in SubstitutableDatabase._create_database(self)
#      32     model.bind(db, bind_refs=False, bind_backrefs=False)
#      33 db.connect()
# ---> 34 db.create_tables(self._tables)
#      35 return db
#
# File ~\Anaconda3\envs\bw2\lib\site-packages\peewee.py:3429, in Database.create_tables(self, models, **options)
#    3427 def create_tables(self, models, **options):
#    3428     for model in sort_models(models):
# -> 3429         model.create_table(**options)
#
# File ~\Anaconda3\envs\bw2\lib\site-packages\peewee.py:6860, in Model.create_table(cls, safe, **options)
#    6858 if cls._meta.temporary:
#    6859     options.setdefault('temporary', cls._meta.temporary)
# -> 6860 cls._schema.create_all(safe, **options)
#
# File ~\Anaconda3\envs\bw2\lib\site-packages\peewee.py:5962, in SchemaManager.create_all(self, safe, **table_options)
#    5960 def create_all(self, safe=True, **table_options):
#    5961     self.create_sequences()
# -> 5962     self.create_table(safe, **table_options)
#    5963     self.create_indexes(safe=safe)
#
# File ~\Anaconda3\envs\bw2\lib\site-packages\peewee.py:5813, in SchemaManager.create_table(self, safe, **options)
#    5812 def create_table(self, safe=True, **options):
# -> 5813     self.database.execute(self._create_table(safe=safe, **options))
#
# File ~\Anaconda3\envs\bw2\lib\site-packages\peewee.py:3250, in Database.execute(self, query, commit, **context_options)
#    3248 ctx = self.get_sql_context(**context_options)
#    3249 sql, params = ctx.sql(query).query()
# -> 3250 return self.execute_sql(sql, params, commit=commit)
#
# File ~\Anaconda3\envs\bw2\lib\site-packages\peewee.py:3234, in Database.execute_sql(self, sql, params, commit)
#    3231     else:
#    3232         commit = not sql[:6].lower().startswith('select')
# -> 3234 with __exception_wrapper__:
#    3235     cursor = self.cursor(commit)
#    3236     try:
#
# File ~\Anaconda3\envs\bw2\lib\site-packages\peewee.py:3010, in ExceptionWrapper.__exit__(self, exc_type, exc_value, traceback)
#    3008 new_type = self.exceptions[exc_type.__name__]
#    3009 exc_args = exc_value.args
# -> 3010 reraise(new_type, new_type(exc_value, *exc_args), traceback)
#
# File ~\Anaconda3\envs\bw2\lib\site-packages\peewee.py:192, in reraise(tp, value, tb)
#     190 def reraise(tp, value, tb=None):
#     191     if value.__traceback__ is not tb:
# --> 192         raise value.with_traceback(tb)
#     193     raise value
#
# File ~\Anaconda3\envs\bw2\lib\site-packages\peewee.py:3237, in Database.execute_sql(self, sql, params, commit)
#    3235 cursor = self.cursor(commit)
#    3236 try:
# -> 3237     cursor.execute(sql, params or ())
#    3238 except Exception:
#    3239     if self.autorollback and not self.in_transaction():
#
# DatabaseError: file is not a database

# %%
startTime = time.time() # just to see how much time the code takes to run (this is the start)

# %%
bw.projects.set_current('Prospective LCA v2') # set current project

# %%
databaseNames = bw.databases
myDatabaseNames = []
for databaseName in databaseNames:
    if 'Abhi' in databaseName:
        if 'image' in databaseName:
            if 'Base' in databaseName or 'RCP19' in databaseName:
                if '2020' in databaseName or '2050' in databaseName:
                    myDatabaseNames.append(databaseName)

# %%
method = ('IPCC 2013', 'climate change', 'GWP 100a, incl. H and bio CO2')

# %%
for myDatabaseName in myDatabaseNames:

    db = bw.Database(myDatabaseName)

    hydrogenBAU = [activity for activity in db if 'hydrogen, Abhi' in activity['reference product']
                                                and 'hydrogen production without electricity, steam reforming' in activity['name']
                                                and 'GLO' in activity['location']][0]
    fileName = hydrogenBAU['database']
    fileName = fileName.replace('lci-Abhi ', '')
    fileName = fileName.replace('-Base', ' RCP6')
    fileName = fileName.replace('-', ' RCP19')
    sankey(activity = hydrogenBAU,
           level = 5,
           cutoff = 0.05,
           method = method,
           filepath = os.path.join('..', 'Plots', 'Sankey', 'Hydrogen BAU WO Elec ' + fileName + '.html'))
    hydrogenSolar = [activity for activity in db if 'hydrogen, Abhi' in activity['reference product']
                                                and 'solar' in activity['name']
                                                and 'GLO' in activity['location']][0]
    fileName = hydrogenSolar['database']
    fileName = fileName.replace('lci-Abhi ', '')
    fileName = fileName.replace('-Base', ' RCP6')
    fileName = fileName.replace('-', ' RCP19')
    sankey(activity = hydrogenSolar,
           level = 5,
           cutoff = 0.02,
           method = method,
           filepath = os.path.join('..', 'Plots', 'Sankey', 'Hydrogen solar ' + fileName + '.html'))

    hydrogenWind = [activity for activity in db if 'hydrogen, Abhi' in activity['reference product']
                                                and 'onshore wind' in activity['name']
                                                and 'GLO' in activity['location']][0]
    fileName = hydrogenWind['database']
    fileName = fileName.replace('lci-Abhi ', '')
    fileName = fileName.replace('-Base', ' RCP6')
    fileName = fileName.replace('-', ' RCP19')
    sankey(activity = hydrogenWind,
           level = 5,
           cutoff = 0.02,
           method = method,
           filepath = os.path.join('..', 'Plots', 'Sankey', 'Hydrogen wind ' + fileName + '.html'))

    ammoniaBAU = [activity for activity in db if 'ammonia, Abhi' in activity['reference product']
                                                and 'ammonia, BAU' in activity['name']
                                                and 'GLO' in activity['location']][0]
    fileName = ammoniaBAU['database']
    fileName = fileName.replace('lci-Abhi ', '')
    fileName = fileName.replace('-Base', ' RCP6')
    fileName = fileName.replace('-', ' RCP19')
    sankey(activity = ammoniaBAU,
        level = 5,
        cutoff = 0.05,
        method = method,
        filepath = os.path.join('..', 'Plots', 'Sankey', 'Ammonia BAU ' + fileName + '.html'))

    ammoniaSolar = [activity for activity in db if 'ammonia, Abhi' in activity['reference product']
                                                and 'solar' in activity['name']
                                                and 'GLO' in activity['location']][0]
    fileName = ammoniaSolar['database']
    fileName = fileName.replace('lci-Abhi ', '')
    fileName = fileName.replace('-Base', ' RCP6')
    fileName = fileName.replace('-', ' RCP19')
    sankey(activity = ammoniaSolar,
        level = 5,
        cutoff = 0.02,
        method = method,
        filepath = os.path.join('..', 'Plots', 'Sankey', 'Ammonia solar ' + fileName + '.html'))

    ammoniaWind = [activity for activity in db if 'Ammonia, Abhi' in activity['reference product']
                                                and 'onshore wind' in activity['name']
                                                and 'GLO' in activity['location']][0]
    fileName = ammoniaWind['database']
    fileName = fileName.replace('lci-Abhi ', '')
    fileName = fileName.replace('-Base', ' RCP6')
    fileName = fileName.replace('-', ' RCP19')
    sankey(activity = ammoniaWind,
        level = 5,
        cutoff = 0.02,
        method = method,
        filepath = os.path.join('..', 'Plots', 'Sankey', 'Ammonia wind ' + fileName + '.html'))

    methanolBAU = [activity for activity in db if 'methanol, Abhi' in activity['reference product']
                                                and 'methanol, BAU' in activity['name']
                                                and 'GLO' in activity['location']][0]
    fileName = methanolBAU['database']
    fileName = fileName.replace('lci-Abhi ', '')
    fileName = fileName.replace('-Base', ' RCP6')
    fileName = fileName.replace('-', ' RCP19')
    sankey(activity = methanolBAU,
        level = 5,
        cutoff = 0.05,
        method = method,
        filepath = os.path.join('..', 'Plots', 'Sankey', 'Methanol BAU ' + fileName + '.html'))

    methanolSolar = [activity for activity in db if 'methanol, Abhi' in activity['reference product']
                                                and 'methanol synthesis, hydrogen production, gaseous, 200 bar, from PEM electrolysis, from solar electricity carbon dioxide, captured from atmosphere, with a solvent-based direct air capture system, 1MtCO2, with heat pump heat, and onshore wind electricity' in activity['name']
                                                and 'GLO' in activity['location']][0]
    fileName = methanolSolar['database']
    fileName = fileName.replace('lci-Abhi ', '')
    fileName = fileName.replace('-Base', ' RCP6')
    fileName = fileName.replace('-', ' RCP19')
    sankey(activity = methanolSolar,
        level = 5,
        cutoff = 0.02,
        method = method,
        filepath = os.path.join('..', 'Plots', 'Sankey', 'Methanol solar ' + fileName + '.html'))

    methanolWind = [activity for activity in db if 'methanol, Abhi' in activity['reference product']
                                                and 'methanol synthesis, hydrogen production, gaseous, 200 bar, from PEM electrolysis, from onshore wind electricity carbon dioxide, captured from atmosphere, with a solvent-based direct air capture system, 1MtCO2, with heat pump heat, and onshore wind electricity' in activity['name']
                                                and 'GLO' in activity['location']][0]
    fileName = methanolWind['database']
    fileName = fileName.replace('lci-Abhi ', '')
    fileName = fileName.replace('-Base', ' RCP6')
    fileName = fileName.replace('-', ' RCP19')
    sankey(activity = methanolWind,
        level = 5,
        cutoff = 0.02,
        method = method,
        filepath = os.path.join('..', 'Plots', 'Sankey', 'Methanol wind ' + fileName + '.html'))

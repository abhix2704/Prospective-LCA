# %%
import brightway2 as bw
from premise import *
import time

# %%
startTime = time.time() # just to see how much time the code takes to run (this is the start)
bw.projects.set_current('Prospective LCA v2') # set an current project

# %%
bw.databases
# Out:
# Databases dictionary with 2 object(s):
# 	biosphere3
# 	ecoinvent 3.8 cutoff

# %%
bioSphereDB = bw.Database('biosphere3') # import the biosphere database
ecoInventDB = bw.Database('ecoinvent 3.8 cutoff') # import the ecoinvent database (cutoff 3.8)

# %%
clear_cache()
# Out:
# Cache folder cleared!

# %%
scenarios = [{'model' : 'image', 'pathway' : 'SSP2-Base', 'year' : 2020},
             {'model' : 'image', 'pathway' : 'SSP2-Base', 'year' : 2030},
             {'model' : 'image', 'pathway' : 'SSP2-Base', 'year' : 2040},
             {'model' : 'image', 'pathway' : 'SSP2-Base', 'year' : 2050},
             {'model' : 'image', 'pathway' : 'SSP2-RCP19', 'year' : 2030},
             {'model' : 'image', 'pathway' : 'SSP2-RCP19', 'year' : 2040},
             {'model' : 'image', 'pathway' : 'SSP2-RCP19', 'year' : 2050},
             {'model' : 'image', 'pathway' : 'SSP2-RCP26', 'year' : 2030},
             {'model' : 'image', 'pathway' : 'SSP2-RCP26', 'year' : 2040},
             {'model' : 'image', 'pathway' : 'SSP2-RCP26', 'year' : 2050},
             {'model' : 'remind', 'pathway' : 'SSP1-PkBudg1150', 'year' : 2030},
             {'model' : 'remind', 'pathway' : 'SSP1-PkBudg1150', 'year' : 2040},
             {'model' : 'remind', 'pathway' : 'SSP1-PkBudg1150', 'year' : 2050},
             {'model' : 'remind', 'pathway' : 'SSP1-PkBudg500', 'year' : 2030},
             {'model' : 'remind', 'pathway' : 'SSP1-PkBudg500', 'year' : 2040},
             {'model' : 'remind', 'pathway' : 'SSP1-PkBudg500', 'year' : 2050},
             {'model' : 'remind', 'pathway' : 'SSP2-Base', 'year' : 2030},
             {'model' : 'remind', 'pathway' : 'SSP2-Base', 'year' : 2040},
             {'model' : 'remind', 'pathway' : 'SSP2-Base', 'year' : 2050},
             {'model' : 'remind', 'pathway' : 'SSP2-PkBudg1150', 'year' : 2030},
             {'model' : 'remind', 'pathway' : 'SSP2-PkBudg1150', 'year' : 2040},
             {'model' : 'remind', 'pathway' : 'SSP2-PkBudg1150', 'year' : 2050},
             {'model' : 'remind', 'pathway' : 'SSP2-PkBudg500', 'year' : 2030},
             {'model' : 'remind', 'pathway' : 'SSP2-PkBudg500', 'year' : 2040},
             {'model' : 'remind', 'pathway' : 'SSP2-PkBudg500', 'year' : 2050},
             {'model' : 'remind', 'pathway' : 'SSP5-PkBudg1150', 'year' : 2030},
             {'model' : 'remind', 'pathway' : 'SSP5-PkBudg1150', 'year' : 2040},
             {'model' : 'remind', 'pathway' : 'SSP5-PkBudg1150', 'year' : 2050},
             {'model' : 'remind', 'pathway' : 'SSP5-PkBudg500', 'year' : 2030},
             {'model' : 'remind', 'pathway' : 'SSP5-PkBudg500', 'year' : 2040},
             {'model' : 'remind', 'pathway' : 'SSP5-PkBudg500', 'year' : 2050},
            ]

databaseNames = []
for scenario in scenarios:
    databaseNames.append(f"ecoinvent 3.8 cutoff {scenario['model']} {scenario['pathway']} {scenario['year']}")

# %%
newDataBase = NewDatabase(scenarios = scenarios,
                          source_db = 'ecoinvent 3.8 cutoff',
                          source_version = '3.8',
                          key = 'tUePmX_S5B8ieZkkM7WUU2CnO8SmShwmAeWK9x2rTFo=')
# Out:
# premise v.(1, 5, 6)
# +------------------------------------------------------------------+
# | Warning                                                          |
# +------------------------------------------------------------------+
# | Because some of the scenarios can yield LCI databases            |
# | containing net negative emission technologies (NET),             |
# | it is advised to account for biogenic CO2 flows when calculating |
# | Global Warming potential indicators.                             |
# | `premise_gwp` provides characterization factors for such flows.  |
# | It also provides factors for hydrogen emissions to air.          |
# |                                                                  |
# | Within your bw2 project:                                         |
# | from premise_gwp import add_premise_gwp                          |
# | add_premise_gwp()                                                |
# +------------------------------------------------------------------+
# +--------------------------------+----------------------------------+
# | Utils functions                | Description                      |
# +--------------------------------+----------------------------------+
# | clear_cache()                  | Clears the cache folder. Useful  |
# |                                | when updating `premise`or        |
# |                                | encountering issues with         |
# |                                | inventories.                     |
# +--------------------------------+----------------------------------+
# | get_regions_definition(model)  | Retrieves the list of countries  |
# |                                | for each region of the model.    |
# +--------------------------------+----------------------------------+
# | ndb.NewDatabase(...)           | Generates a summary of the most  |
# | ndb.generate_scenario_report() | important scenarios' variables.  |
# +--------------------------------+----------------------------------+
# Keep uncertainty data?
# NewDatabase(..., keep_uncertainty_data=True)
#
# Hide these messages?
# NewDatabase(..., quiet=True)
#
# //////////////////// EXTRACTING SOURCE DATABASE ////////////////////
# Cannot find cached database. Will create one now for next time...
# Getting activity data
# 100%|██████████| 19565/19565 [00:00<00:00, 117444.71it/s]
# Adding exchange data to activities
# 100%|██████████| 629959/629959 [00:14<00:00, 43840.87it/s]
# Filling out exchange data
# 100%|██████████| 19565/19565 [00:01<00:00, 18803.80it/s]
# Set missing location of datasets to global scope.
# Set missing location of production exchanges to scope of dataset.
# Correct missing location of technosphere exchanges.
# Correct missing flow categories for biosphere exchanges
# Remove empty exchanges.
# Remove uncertainty data.
# Done!
#
# ////////////////// IMPORTING DEFAULT INVENTORIES ///////////////////
# Cannot find cached inventories. Will create them now for next time...
# Importing default inventories...
#
# Extracted 1 worksheets in 0.16 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.15 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.01 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.01 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.01 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.01 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 7 worksheets in 0.02 seconds
# Remove uncertainty data.
# Extracted 1 worksheets in 0.02 seconds
# Remove uncertainty data.
# Extracted 1 worksheets in 0.01 seconds
# Remove uncertainty data.
# Extracted 1 worksheets in 0.02 seconds
# Remove uncertainty data.
# Extracted 1 worksheets in 0.28 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# The following datasets to import already exist in the source database. They will not be imported
# +----------------------------------------------------+--------------------------------+----------+-------------+
# |                        Name                        |       Reference product        | Location |     File    |
# +----------------------------------------------------+--------------------------------+----------+-------------+
# |          fluorspar production, 97% purity          |     fluorspar, 97% purity      |   GLO    | lci-PV.xlsx |
# |     metallization paste production, back side      | metallization paste, back side |   RER    | lci-PV.xlsx |
# | metallization paste production, back side, alumini | metallization paste, back side |   RER    | lci-PV.xlsx |
# |     metallization paste production, front side     | metallization paste, front sid |   RER    | lci-PV.xlsx |
# | photovoltaic module production, building-integrate | photovoltaic module, building- |   RER    | lci-PV.xlsx |
# | photovoltaic module production, building-integrate | photovoltaic module, building- |   RER    | lci-PV.xlsx |
# | photovoltaic mounting system production, for facad | photovoltaic mounting system,  |   RER    | lci-PV.xlsx |
# | photovoltaic mounting system production, for flat- | photovoltaic mounting system,  |   RER    | lci-PV.xlsx |
# | photovoltaic mounting system production, for slant | photovoltaic mounting system,  |   RER    | lci-PV.xlsx |
# |      photovoltaic panel factory construction       |   photovoltaic panel factory   |   GLO    | lci-PV.xlsx |
# |            polyvinylfluoride production            |       polyvinylfluoride        |    US    | lci-PV.xlsx |
# |      polyvinylfluoride production, dispersion      | polyvinylfluoride, dispersion  |    US    | lci-PV.xlsx |
# |         polyvinylfluoride, film production         |    polyvinylfluoride, film     |    US    | lci-PV.xlsx |
# |      silicon production, metallurgical grade       |  silicon, metallurgical grade  |    NO    | lci-PV.xlsx |
# |             vinyl fluoride production              |         vinyl fluoride         |    US    | lci-PV.xlsx |
# |             wafer factory construction             |         wafer factory          |    DE    | lci-PV.xlsx |
# +----------------------------------------------------+--------------------------------+----------+-------------+
# Extracted 1 worksheets in 0.02 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.01 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.01 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.01 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.01 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# The following datasets to import already exist in the source database. They will not be imported
# +----------------------------------------------------+--------------------------------+----------+---------------------------------------------------+
# |                        Name                        |       Reference product        | Location |                        File                       |
# +----------------------------------------------------+--------------------------------+----------+---------------------------------------------------+
# | carbon dioxide, captured at cement production plan | carbon dioxide, captured and r |   RER    | lci-synfuels-from-methanol-from-cement-plant.xlsx |
# +----------------------------------------------------+--------------------------------+----------+---------------------------------------------------+
# Extracted 1 worksheets in 0.01 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.01 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# The following datasets to import already exist in the source database. They will not be imported
# +----------------------------------------------------+----------------------+----------+-------------------------------------------+
# |                        Name                        |  Reference product   | Location |                    File                   |
# +----------------------------------------------------+----------------------+----------+-------------------------------------------+
# | methanol distillation, hydrogen from coal gasifica |  methanol, purified  |   RER    | lci-synfuels-from-methanol-from-coal.xlsx |
# | methanol synthesis, hydrogen from coal gasificatio | methanol, unpurified |   RER    | lci-synfuels-from-methanol-from-coal.xlsx |
# +----------------------------------------------------+----------------------+----------+-------------------------------------------+
# Extracted 1 worksheets in 0.01 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.01 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.01 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.01 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.00 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.02 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.00 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 4 worksheets in 0.12 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.02 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.01 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.01 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.01 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.01 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.02 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.01 seconds
# Remove uncertainty data.
# Extracted 1 worksheets in 0.06 seconds
# Remove uncertainty data.
# Extracted 1 worksheets in 0.01 seconds
# Remove uncertainty data.
# Extracted 1 worksheets in 0.01 seconds
# Remove uncertainty data.
# Extracted 1 worksheets in 0.02 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Done!
#
# Data cached. It is advised to restart your workflow at this point.
# This allows premise to use the cached data instead, which results in
# a faster workflow.
# Done!
#
# /////////////////////// EXTRACTING IAM DATA ////////////////////////
# Done!

# %%
newDataBase.update_all()
# Out:
# `update_all()` will skip the following steps:
# update_two_wheelers(), update_cars(), and update_buses()
# If you want to update these steps, please run them separately afterwards.
#
# ////////////////// MEDIUM AND HEAVY DUTY TRUCKS ////////////////////
# Extracted 1 worksheets in 2.04 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Create fleet average vehicles...
# Done!
# Extracted 1 worksheets in 2.03 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Create fleet average vehicles...
# Done!
# Extracted 1 worksheets in 2.06 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Create fleet average vehicles...
# Done!
# Extracted 1 worksheets in 2.03 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Create fleet average vehicles...
# Done!
# Extracted 1 worksheets in 2.03 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Create fleet average vehicles...
# Done!
# Extracted 1 worksheets in 8.57 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Create fleet average vehicles...
# Done!
# Extracted 1 worksheets in 2.04 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Create fleet average vehicles...
# Done!
# Extracted 1 worksheets in 2.06 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Create fleet average vehicles...
# Done!
# Extracted 1 worksheets in 8.35 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Create fleet average vehicles...
# Done!
# Extracted 1 worksheets in 2.03 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Create fleet average vehicles...
# Done!
# Extracted 1 worksheets in 2.03 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Create fleet average vehicles...
# Done!
# Extracted 1 worksheets in 2.03 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Create fleet average vehicles...
# Done!
# Extracted 1 worksheets in 8.60 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Create fleet average vehicles...
# Done!
# Extracted 1 worksheets in 2.03 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Create fleet average vehicles...
# Done!
# Extracted 1 worksheets in 2.03 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Create fleet average vehicles...
# Done!
# Extracted 1 worksheets in 8.81 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Create fleet average vehicles...
# Done!
# Extracted 1 worksheets in 2.04 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Create fleet average vehicles...
# Done!
# Extracted 1 worksheets in 2.05 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Create fleet average vehicles...
# Done!
# Extracted 1 worksheets in 8.78 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Create fleet average vehicles...
# Done!
# Extracted 1 worksheets in 2.04 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Create fleet average vehicles...
# Done!
# Extracted 1 worksheets in 2.03 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Create fleet average vehicles...
# Done!
# Extracted 1 worksheets in 2.04 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Create fleet average vehicles...
# Done!
# Extracted 1 worksheets in 8.86 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Create fleet average vehicles...
# Done!
# Extracted 1 worksheets in 2.04 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Create fleet average vehicles...
# Done!
# Extracted 1 worksheets in 2.04 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Create fleet average vehicles...
# Done!
# Extracted 1 worksheets in 8.89 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Create fleet average vehicles...
# Done!
# Extracted 1 worksheets in 2.04 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Create fleet average vehicles...
# Done!
# Extracted 1 worksheets in 2.03 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Create fleet average vehicles...
# Done!
# Extracted 1 worksheets in 2.03 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Create fleet average vehicles...
# Done!
# Extracted 1 worksheets in 2.04 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Create fleet average vehicles...
# Done!
# Extracted 1 worksheets in 2.03 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Create fleet average vehicles...
# Done!
#
# /////////////////////////// ELECTRICITY ////////////////////////////
# Update natural gas extraction datasets.
# Update efficiency of solar PV panels.
# Create biomass markets.
# Replace biomass inputs.
# Create region-specific power plants.
# Empty old electricity datasets
# Create high voltage markets.
# Create medium voltage markets.
# Create low voltage markets.
# Done!
# Adjust efficiency of power plants...
# Rescale inventories and emissions for Biomass CHP CCS
# Rescale inventories and emissions for Oil CHP CCS
# Rescale inventories and emissions for Biomass CHP
# Rescale inventories and emissions for Coal IGCC
# Rescale inventories and emissions for Oil CC CCS
# Rescale inventories and emissions for Coal CHP CCS
# Rescale inventories and emissions for Biomass ST
# Rescale inventories and emissions for Gas CHP
# Rescale inventories and emissions for Oil CC
# Rescale inventories and emissions for Coal IGCC CCS
# Rescale inventories and emissions for Coal CHP
# Rescale inventories and emissions for Gas OC
# Rescale inventories and emissions for Gas CC CCS
# Rescale inventories and emissions for Coal PC
# Rescale inventories and emissions for Biomass IGCC
# Rescale inventories and emissions for Oil CHP
# Rescale inventories and emissions for Gas CC
# Rescale inventories and emissions for Nuclear
# Rescale inventories and emissions for Biomass IGCC CCS
# Rescale inventories and emissions for Oil ST
# Rescale inventories and emissions for Gas CHP CCS
# Update natural gas extraction datasets.
# Update efficiency of solar PV panels.
# Create biomass markets.
# Replace biomass inputs.
# Create region-specific power plants.
# Empty old electricity datasets
# Create high voltage markets.
# Create medium voltage markets.
# Create low voltage markets.
# Done!
# Adjust efficiency of power plants...
# Rescale inventories and emissions for Biomass CHP CCS
# Rescale inventories and emissions for Oil CHP CCS
# Rescale inventories and emissions for Biomass CHP
# Rescale inventories and emissions for Coal IGCC
# Rescale inventories and emissions for Oil CC CCS
# Rescale inventories and emissions for Coal CHP CCS
# Rescale inventories and emissions for Biomass ST
# Rescale inventories and emissions for Gas CHP
# Rescale inventories and emissions for Oil CC
# Rescale inventories and emissions for Coal IGCC CCS
# Rescale inventories and emissions for Coal CHP
# Rescale inventories and emissions for Gas OC
# Rescale inventories and emissions for Gas CC CCS
# Rescale inventories and emissions for Coal PC
# Rescale inventories and emissions for Biomass IGCC
# Rescale inventories and emissions for Oil CHP
# Rescale inventories and emissions for Gas CC
# Rescale inventories and emissions for Nuclear
# Rescale inventories and emissions for Biomass IGCC CCS
# Rescale inventories and emissions for Oil ST
# Rescale inventories and emissions for Gas CHP CCS
# Update natural gas extraction datasets.
# Update efficiency of solar PV panels.
# Create biomass markets.
# Replace biomass inputs.
# Create region-specific power plants.
# Empty old electricity datasets
# Create high voltage markets.
# Create medium voltage markets.
# Create low voltage markets.
# Done!
# Adjust efficiency of power plants...
# Rescale inventories and emissions for Biomass CHP CCS
# Rescale inventories and emissions for Oil CHP CCS
# Rescale inventories and emissions for Biomass CHP
# Rescale inventories and emissions for Coal IGCC
# Rescale inventories and emissions for Oil CC CCS
# Rescale inventories and emissions for Coal CHP CCS
# Rescale inventories and emissions for Biomass ST
# Rescale inventories and emissions for Gas CHP
# Rescale inventories and emissions for Oil CC
# Rescale inventories and emissions for Coal IGCC CCS
# Rescale inventories and emissions for Coal CHP
# Rescale inventories and emissions for Gas OC
# Rescale inventories and emissions for Gas CC CCS
# Rescale inventories and emissions for Coal PC
# Rescale inventories and emissions for Biomass IGCC
# Rescale inventories and emissions for Oil CHP
# Rescale inventories and emissions for Gas CC
# Rescale inventories and emissions for Nuclear
# Rescale inventories and emissions for Biomass IGCC CCS
# Rescale inventories and emissions for Oil ST
# Rescale inventories and emissions for Gas CHP CCS
# Update natural gas extraction datasets.
# Update efficiency of solar PV panels.
# Create biomass markets.
# Replace biomass inputs.
# Create region-specific power plants.
# Empty old electricity datasets
# Create high voltage markets.
# Create medium voltage markets.
# Create low voltage markets.
# Done!
# Adjust efficiency of power plants...
# Rescale inventories and emissions for Biomass CHP CCS
# Rescale inventories and emissions for Oil CHP CCS
# Rescale inventories and emissions for Biomass CHP
# Rescale inventories and emissions for Coal IGCC
# Rescale inventories and emissions for Oil CC CCS
# Rescale inventories and emissions for Coal CHP CCS
# Rescale inventories and emissions for Biomass ST
# Rescale inventories and emissions for Gas CHP
# Rescale inventories and emissions for Oil CC
# Rescale inventories and emissions for Coal IGCC CCS
# Rescale inventories and emissions for Coal CHP
# Rescale inventories and emissions for Gas OC
# Rescale inventories and emissions for Gas CC CCS
# Rescale inventories and emissions for Coal PC
# Rescale inventories and emissions for Biomass IGCC
# Rescale inventories and emissions for Oil CHP
# Rescale inventories and emissions for Gas CC
# Rescale inventories and emissions for Nuclear
# Rescale inventories and emissions for Biomass IGCC CCS
# Rescale inventories and emissions for Oil ST
# Rescale inventories and emissions for Gas CHP CCS
# Update natural gas extraction datasets.
# Update efficiency of solar PV panels.
# Create biomass markets.
# Replace biomass inputs.
# Create region-specific power plants.
# Empty old electricity datasets
# Create high voltage markets.
# Create medium voltage markets.
# Create low voltage markets.
# Done!
# Adjust efficiency of power plants...
# Rescale inventories and emissions for Biomass CHP CCS
# Rescale inventories and emissions for Oil CHP CCS
# Rescale inventories and emissions for Biomass CHP
# Rescale inventories and emissions for Coal IGCC
# Rescale inventories and emissions for Oil CC CCS
# Rescale inventories and emissions for Coal CHP CCS
# Rescale inventories and emissions for Biomass ST
# Rescale inventories and emissions for Gas CHP
# Rescale inventories and emissions for Oil CC
# Rescale inventories and emissions for Coal IGCC CCS
# Rescale inventories and emissions for Coal CHP
# Rescale inventories and emissions for Gas OC
# Rescale inventories and emissions for Gas CC CCS
# Rescale inventories and emissions for Coal PC
# Rescale inventories and emissions for Biomass IGCC
# Rescale inventories and emissions for Oil CHP
# Rescale inventories and emissions for Gas CC
# Rescale inventories and emissions for Nuclear
# Rescale inventories and emissions for Biomass IGCC CCS
# Rescale inventories and emissions for Oil ST
# Rescale inventories and emissions for Gas CHP CCS
# Update natural gas extraction datasets.
# Update efficiency of solar PV panels.
# Create biomass markets.
# Replace biomass inputs.
# Create region-specific power plants.
# Empty old electricity datasets
# Create high voltage markets.
# Create medium voltage markets.
# Create low voltage markets.
# Done!
# Adjust efficiency of power plants...
# Rescale inventories and emissions for Biomass CHP CCS
# Rescale inventories and emissions for Oil CHP CCS
# Rescale inventories and emissions for Biomass CHP
# Rescale inventories and emissions for Coal IGCC
# Rescale inventories and emissions for Oil CC CCS
# Rescale inventories and emissions for Coal CHP CCS
# Rescale inventories and emissions for Biomass ST
# Rescale inventories and emissions for Gas CHP
# Rescale inventories and emissions for Oil CC
# Rescale inventories and emissions for Coal IGCC CCS
# Rescale inventories and emissions for Coal CHP
# Rescale inventories and emissions for Gas OC
# Rescale inventories and emissions for Gas CC CCS
# Rescale inventories and emissions for Coal PC
# Rescale inventories and emissions for Biomass IGCC
# Rescale inventories and emissions for Oil CHP
# Rescale inventories and emissions for Gas CC
# Rescale inventories and emissions for Nuclear
# Rescale inventories and emissions for Biomass IGCC CCS
# Rescale inventories and emissions for Oil ST
# Rescale inventories and emissions for Gas CHP CCS
# Update natural gas extraction datasets.
# Update efficiency of solar PV panels.
# Create biomass markets.
# Replace biomass inputs.
# Create region-specific power plants.
# Empty old electricity datasets
# Create high voltage markets.
# Create medium voltage markets.
# Create low voltage markets.
# Done!
# Adjust efficiency of power plants...
# Rescale inventories and emissions for Biomass CHP CCS
# Rescale inventories and emissions for Oil CHP CCS
# Rescale inventories and emissions for Biomass CHP
# Rescale inventories and emissions for Coal IGCC
# Rescale inventories and emissions for Oil CC CCS
# Rescale inventories and emissions for Coal CHP CCS
# Rescale inventories and emissions for Biomass ST
# Rescale inventories and emissions for Gas CHP
# Rescale inventories and emissions for Oil CC
# Rescale inventories and emissions for Coal IGCC CCS
# Rescale inventories and emissions for Coal CHP
# Rescale inventories and emissions for Gas OC
# Rescale inventories and emissions for Gas CC CCS
# Rescale inventories and emissions for Coal PC
# Rescale inventories and emissions for Biomass IGCC
# Rescale inventories and emissions for Oil CHP
# Rescale inventories and emissions for Gas CC
# Rescale inventories and emissions for Nuclear
# Rescale inventories and emissions for Biomass IGCC CCS
# Rescale inventories and emissions for Oil ST
# Rescale inventories and emissions for Gas CHP CCS
# Update natural gas extraction datasets.
# Update efficiency of solar PV panels.
# Create biomass markets.
# Replace biomass inputs.
# Create region-specific power plants.
# Empty old electricity datasets
# Create high voltage markets.
# Create medium voltage markets.
# Create low voltage markets.
# Done!
# Adjust efficiency of power plants...
# Rescale inventories and emissions for Biomass CHP CCS
# Rescale inventories and emissions for Oil CHP CCS
# Rescale inventories and emissions for Biomass CHP
# Rescale inventories and emissions for Coal IGCC
# Rescale inventories and emissions for Oil CC CCS
# Rescale inventories and emissions for Coal CHP CCS
# Rescale inventories and emissions for Biomass ST
# Rescale inventories and emissions for Gas CHP
# Rescale inventories and emissions for Oil CC
# Rescale inventories and emissions for Coal IGCC CCS
# Rescale inventories and emissions for Coal CHP
# Rescale inventories and emissions for Gas OC
# Rescale inventories and emissions for Gas CC CCS
# Rescale inventories and emissions for Coal PC
# Rescale inventories and emissions for Biomass IGCC
# Rescale inventories and emissions for Oil CHP
# Rescale inventories and emissions for Gas CC
# Rescale inventories and emissions for Nuclear
# Rescale inventories and emissions for Biomass IGCC CCS
# Rescale inventories and emissions for Oil ST
# Rescale inventories and emissions for Gas CHP CCS
# Update natural gas extraction datasets.
# Update efficiency of solar PV panels.
# Create biomass markets.
# Replace biomass inputs.
# Create region-specific power plants.
# Empty old electricity datasets
# Create high voltage markets.
# Create medium voltage markets.
# Create low voltage markets.
# Done!
# Adjust efficiency of power plants...
# Rescale inventories and emissions for Biomass CHP CCS
# Rescale inventories and emissions for Oil CHP CCS
# Rescale inventories and emissions for Biomass CHP
# Rescale inventories and emissions for Coal IGCC
# Rescale inventories and emissions for Oil CC CCS
# Rescale inventories and emissions for Coal CHP CCS
# Rescale inventories and emissions for Biomass ST
# Rescale inventories and emissions for Gas CHP
# Rescale inventories and emissions for Oil CC
# Rescale inventories and emissions for Coal IGCC CCS
# Rescale inventories and emissions for Coal CHP
# Rescale inventories and emissions for Gas OC
# Rescale inventories and emissions for Gas CC CCS
# Rescale inventories and emissions for Coal PC
# Rescale inventories and emissions for Biomass IGCC
# Rescale inventories and emissions for Oil CHP
# Rescale inventories and emissions for Gas CC
# Rescale inventories and emissions for Nuclear
# Rescale inventories and emissions for Biomass IGCC CCS
# Rescale inventories and emissions for Oil ST
# Rescale inventories and emissions for Gas CHP CCS
# Update natural gas extraction datasets.
# Update efficiency of solar PV panels.
# Create biomass markets.
# Replace biomass inputs.
# Create region-specific power plants.
# Empty old electricity datasets
# Create high voltage markets.
# Create medium voltage markets.
# Create low voltage markets.
# Done!
# Adjust efficiency of power plants...
# Rescale inventories and emissions for Biomass CHP CCS
# Rescale inventories and emissions for Oil CHP CCS
# Rescale inventories and emissions for Biomass CHP
# Rescale inventories and emissions for Coal IGCC
# Rescale inventories and emissions for Oil CC CCS
# Rescale inventories and emissions for Coal CHP CCS
# Rescale inventories and emissions for Biomass ST
# Rescale inventories and emissions for Gas CHP
# Rescale inventories and emissions for Oil CC
# Rescale inventories and emissions for Coal IGCC CCS
# Rescale inventories and emissions for Coal CHP
# Rescale inventories and emissions for Gas OC
# Rescale inventories and emissions for Gas CC CCS
# Rescale inventories and emissions for Coal PC
# Rescale inventories and emissions for Biomass IGCC
# Rescale inventories and emissions for Oil CHP
# Rescale inventories and emissions for Gas CC
# Rescale inventories and emissions for Nuclear
# Rescale inventories and emissions for Biomass IGCC CCS
# Rescale inventories and emissions for Oil ST
# Rescale inventories and emissions for Gas CHP CCS
# Update natural gas extraction datasets.
# Update efficiency of solar PV panels.
# Create biomass markets.
# Replace biomass inputs.
# Create region-specific power plants.
# Empty old electricity datasets
# Create high voltage markets.
# Create medium voltage markets.
# Create low voltage markets.
# Done!
# Adjust efficiency of power plants...
# Rescale inventories and emissions for Gas OC
# Rescale inventories and emissions for Biomass CHP
# Rescale inventories and emissions for Coal PC CCS
# Rescale inventories and emissions for Gas CC
# Rescale inventories and emissions for Gas CHP
# Rescale inventories and emissions for Biomass IGCC CCS
# Rescale inventories and emissions for Coal IGCC
# Rescale inventories and emissions for Gas CC CCS
# Rescale inventories and emissions for Coal PC
# Rescale inventories and emissions for Coal IGCC CCS
# Rescale inventories and emissions for Coal CHP
# Rescale inventories and emissions for Biomass IGCC
# Rescale inventories and emissions for Oil ST
# Update natural gas extraction datasets.
# Update efficiency of solar PV panels.
# Create biomass markets.
# Replace biomass inputs.
# Create region-specific power plants.
# Empty old electricity datasets
# Create high voltage markets.
# Create medium voltage markets.
# Create low voltage markets.
# Done!
# Adjust efficiency of power plants...
# Rescale inventories and emissions for Gas OC
# Rescale inventories and emissions for Biomass CHP
# Rescale inventories and emissions for Coal PC CCS
# Rescale inventories and emissions for Gas CC
# Rescale inventories and emissions for Gas CHP
# Rescale inventories and emissions for Biomass IGCC CCS
# Rescale inventories and emissions for Coal IGCC
# Rescale inventories and emissions for Gas CC CCS
# Rescale inventories and emissions for Coal PC
# Rescale inventories and emissions for Coal IGCC CCS
# Rescale inventories and emissions for Coal CHP
# Rescale inventories and emissions for Biomass IGCC
# Rescale inventories and emissions for Oil ST
# Update natural gas extraction datasets.
# Update efficiency of solar PV panels.
# Create biomass markets.
# Replace biomass inputs.
# Create region-specific power plants.
# Empty old electricity datasets
# Create high voltage markets.
# Create medium voltage markets.
# Create low voltage markets.
# Done!
# Adjust efficiency of power plants...
# Rescale inventories and emissions for Gas OC
# Rescale inventories and emissions for Biomass CHP
# Rescale inventories and emissions for Coal PC CCS
# Rescale inventories and emissions for Gas CC
# Rescale inventories and emissions for Gas CHP
# Rescale inventories and emissions for Biomass IGCC CCS
# Rescale inventories and emissions for Coal IGCC
# Rescale inventories and emissions for Gas CC CCS
# Rescale inventories and emissions for Coal PC
# Rescale inventories and emissions for Coal IGCC CCS
# Rescale inventories and emissions for Coal CHP
# Rescale inventories and emissions for Biomass IGCC
# Rescale inventories and emissions for Oil ST
# Update natural gas extraction datasets.
# Update efficiency of solar PV panels.
# Create biomass markets.
# Replace biomass inputs.
# Create region-specific power plants.
# Empty old electricity datasets
# Create high voltage markets.
# Create medium voltage markets.
# Create low voltage markets.
# Done!
# Adjust efficiency of power plants...
# Rescale inventories and emissions for Gas OC
# Rescale inventories and emissions for Biomass CHP
# Rescale inventories and emissions for Coal PC CCS
# Rescale inventories and emissions for Gas CC
# Rescale inventories and emissions for Gas CHP
# Rescale inventories and emissions for Biomass IGCC CCS
# Rescale inventories and emissions for Coal IGCC
# Rescale inventories and emissions for Gas CC CCS
# Rescale inventories and emissions for Coal PC
# Rescale inventories and emissions for Coal IGCC CCS
# Rescale inventories and emissions for Coal CHP
# Rescale inventories and emissions for Biomass IGCC
# Rescale inventories and emissions for Oil ST
# Update natural gas extraction datasets.
# Update efficiency of solar PV panels.
# Create biomass markets.
# Replace biomass inputs.
# Create region-specific power plants.
# Empty old electricity datasets
# Create high voltage markets.
# Create medium voltage markets.
# Create low voltage markets.
# Done!
# Adjust efficiency of power plants...
# Rescale inventories and emissions for Gas OC
# Rescale inventories and emissions for Biomass CHP
# Rescale inventories and emissions for Coal PC CCS
# Rescale inventories and emissions for Gas CC
# Rescale inventories and emissions for Gas CHP
# Rescale inventories and emissions for Biomass IGCC CCS
# Rescale inventories and emissions for Coal IGCC
# Rescale inventories and emissions for Gas CC CCS
# Rescale inventories and emissions for Coal PC
# Rescale inventories and emissions for Coal IGCC CCS
# Rescale inventories and emissions for Coal CHP
# Rescale inventories and emissions for Biomass IGCC
# Rescale inventories and emissions for Oil ST
# Update natural gas extraction datasets.
# Update efficiency of solar PV panels.
# Create biomass markets.
# Replace biomass inputs.
# Create region-specific power plants.
# Empty old electricity datasets
# Create high voltage markets.
# Create medium voltage markets.
# Create low voltage markets.
# Done!
# Adjust efficiency of power plants...
# Rescale inventories and emissions for Gas OC
# Rescale inventories and emissions for Biomass CHP
# Rescale inventories and emissions for Coal PC CCS
# Rescale inventories and emissions for Gas CC
# Rescale inventories and emissions for Gas CHP
# Rescale inventories and emissions for Biomass IGCC CCS
# Rescale inventories and emissions for Coal IGCC
# Rescale inventories and emissions for Gas CC CCS
# Rescale inventories and emissions for Coal PC
# Rescale inventories and emissions for Coal IGCC CCS
# Rescale inventories and emissions for Coal CHP
# Rescale inventories and emissions for Biomass IGCC
# Rescale inventories and emissions for Oil ST
# Update natural gas extraction datasets.
# Update efficiency of solar PV panels.
# Create biomass markets.
# Replace biomass inputs.
# Create region-specific power plants.
# Empty old electricity datasets
# Create high voltage markets.
# Create medium voltage markets.
# Create low voltage markets.
# Done!
# Adjust efficiency of power plants...
# Rescale inventories and emissions for Gas OC
# Rescale inventories and emissions for Biomass CHP
# Rescale inventories and emissions for Coal PC CCS
# Rescale inventories and emissions for Gas CC
# Rescale inventories and emissions for Gas CHP
# Rescale inventories and emissions for Biomass IGCC CCS
# Rescale inventories and emissions for Coal IGCC
# Rescale inventories and emissions for Gas CC CCS
# Rescale inventories and emissions for Coal PC
# Rescale inventories and emissions for Coal IGCC CCS
# Rescale inventories and emissions for Coal CHP
# Rescale inventories and emissions for Biomass IGCC
# Rescale inventories and emissions for Oil ST
# Update natural gas extraction datasets.
# Update efficiency of solar PV panels.
# Create biomass markets.
# Replace biomass inputs.
# Create region-specific power plants.
# Empty old electricity datasets
# Create high voltage markets.
# Create medium voltage markets.
# Create low voltage markets.
# Done!
# Adjust efficiency of power plants...
# Rescale inventories and emissions for Gas OC
# Rescale inventories and emissions for Biomass CHP
# Rescale inventories and emissions for Coal PC CCS
# Rescale inventories and emissions for Gas CC
# Rescale inventories and emissions for Gas CHP
# Rescale inventories and emissions for Biomass IGCC CCS
# Rescale inventories and emissions for Coal IGCC
# Rescale inventories and emissions for Gas CC CCS
# Rescale inventories and emissions for Coal PC
# Rescale inventories and emissions for Coal IGCC CCS
# Rescale inventories and emissions for Coal CHP
# Rescale inventories and emissions for Biomass IGCC
# Rescale inventories and emissions for Oil ST
# Update natural gas extraction datasets.
# Update efficiency of solar PV panels.
# Create biomass markets.
# Replace biomass inputs.
# Create region-specific power plants.
# Empty old electricity datasets
# Create high voltage markets.
# Create medium voltage markets.
# Create low voltage markets.
# Done!
# Adjust efficiency of power plants...
# Rescale inventories and emissions for Gas OC
# Rescale inventories and emissions for Biomass CHP
# Rescale inventories and emissions for Coal PC CCS
# Rescale inventories and emissions for Gas CC
# Rescale inventories and emissions for Gas CHP
# Rescale inventories and emissions for Biomass IGCC CCS
# Rescale inventories and emissions for Coal IGCC
# Rescale inventories and emissions for Gas CC CCS
# Rescale inventories and emissions for Coal PC
# Rescale inventories and emissions for Coal IGCC CCS
# Rescale inventories and emissions for Coal CHP
# Rescale inventories and emissions for Biomass IGCC
# Rescale inventories and emissions for Oil ST
# Update natural gas extraction datasets.
# Update efficiency of solar PV panels.
# Create biomass markets.
# Replace biomass inputs.
# Create region-specific power plants.
# Empty old electricity datasets
# Create high voltage markets.
# Create medium voltage markets.
# Create low voltage markets.
# Done!
# Adjust efficiency of power plants...
# Rescale inventories and emissions for Gas OC
# Rescale inventories and emissions for Biomass CHP
# Rescale inventories and emissions for Coal PC CCS
# Rescale inventories and emissions for Gas CC
# Rescale inventories and emissions for Gas CHP
# Rescale inventories and emissions for Biomass IGCC CCS
# Rescale inventories and emissions for Coal IGCC
# Rescale inventories and emissions for Gas CC CCS
# Rescale inventories and emissions for Coal PC
# Rescale inventories and emissions for Coal IGCC CCS
# Rescale inventories and emissions for Coal CHP
# Rescale inventories and emissions for Biomass IGCC
# Rescale inventories and emissions for Oil ST
# Update natural gas extraction datasets.
# Update efficiency of solar PV panels.
# Create biomass markets.
# Replace biomass inputs.
# Create region-specific power plants.
# Empty old electricity datasets
# Create high voltage markets.
# Create medium voltage markets.
# Create low voltage markets.
# Done!
# Adjust efficiency of power plants...
# Rescale inventories and emissions for Gas OC
# Rescale inventories and emissions for Biomass CHP
# Rescale inventories and emissions for Coal PC CCS
# Rescale inventories and emissions for Gas CC
# Rescale inventories and emissions for Gas CHP
# Rescale inventories and emissions for Biomass IGCC CCS
# Rescale inventories and emissions for Coal IGCC
# Rescale inventories and emissions for Gas CC CCS
# Rescale inventories and emissions for Coal PC
# Rescale inventories and emissions for Coal IGCC CCS
# Rescale inventories and emissions for Coal CHP
# Rescale inventories and emissions for Biomass IGCC
# Rescale inventories and emissions for Oil ST
# Update natural gas extraction datasets.
# Update efficiency of solar PV panels.
# Create biomass markets.
# Replace biomass inputs.
# Create region-specific power plants.
# Empty old electricity datasets
# Create high voltage markets.
# Create medium voltage markets.
# Create low voltage markets.
# Done!
# Adjust efficiency of power plants...
# Rescale inventories and emissions for Gas OC
# Rescale inventories and emissions for Biomass CHP
# Rescale inventories and emissions for Coal PC CCS
# Rescale inventories and emissions for Gas CC
# Rescale inventories and emissions for Gas CHP
# Rescale inventories and emissions for Biomass IGCC CCS
# Rescale inventories and emissions for Coal IGCC
# Rescale inventories and emissions for Gas CC CCS
# Rescale inventories and emissions for Coal PC
# Rescale inventories and emissions for Coal IGCC CCS
# Rescale inventories and emissions for Coal CHP
# Rescale inventories and emissions for Biomass IGCC
# Rescale inventories and emissions for Oil ST
# Update natural gas extraction datasets.
# Update efficiency of solar PV panels.
# Create biomass markets.
# Replace biomass inputs.
# Create region-specific power plants.
# Empty old electricity datasets
# Create high voltage markets.
# Create medium voltage markets.
# Create low voltage markets.
# Done!
# Adjust efficiency of power plants...
# Rescale inventories and emissions for Gas OC
# Rescale inventories and emissions for Biomass CHP
# Rescale inventories and emissions for Coal PC CCS
# Rescale inventories and emissions for Gas CC
# Rescale inventories and emissions for Gas CHP
# Rescale inventories and emissions for Biomass IGCC CCS
# Rescale inventories and emissions for Coal IGCC
# Rescale inventories and emissions for Gas CC CCS
# Rescale inventories and emissions for Coal PC
# Rescale inventories and emissions for Coal IGCC CCS
# Rescale inventories and emissions for Coal CHP
# Rescale inventories and emissions for Biomass IGCC
# Rescale inventories and emissions for Oil ST
# Update natural gas extraction datasets.
# Update efficiency of solar PV panels.
# Create biomass markets.
# Replace biomass inputs.
# Create region-specific power plants.
# Empty old electricity datasets
# Create high voltage markets.
# Create medium voltage markets.
# Create low voltage markets.
# Done!
# Adjust efficiency of power plants...
# Rescale inventories and emissions for Gas OC
# Rescale inventories and emissions for Biomass CHP
# Rescale inventories and emissions for Coal PC CCS
# Rescale inventories and emissions for Gas CC
# Rescale inventories and emissions for Gas CHP
# Rescale inventories and emissions for Biomass IGCC CCS
# Rescale inventories and emissions for Coal IGCC
# Rescale inventories and emissions for Gas CC CCS
# Rescale inventories and emissions for Coal PC
# Rescale inventories and emissions for Coal IGCC CCS
# Rescale inventories and emissions for Coal CHP
# Rescale inventories and emissions for Biomass IGCC
# Rescale inventories and emissions for Oil ST
# Update natural gas extraction datasets.
# Update efficiency of solar PV panels.
# Create biomass markets.
# Replace biomass inputs.
# Create region-specific power plants.
# Empty old electricity datasets
# Create high voltage markets.
# Create medium voltage markets.
# Create low voltage markets.
# Done!
# Adjust efficiency of power plants...
# Rescale inventories and emissions for Gas OC
# Rescale inventories and emissions for Biomass CHP
# Rescale inventories and emissions for Coal PC CCS
# Rescale inventories and emissions for Gas CC
# Rescale inventories and emissions for Gas CHP
# Rescale inventories and emissions for Biomass IGCC CCS
# Rescale inventories and emissions for Coal IGCC
# Rescale inventories and emissions for Gas CC CCS
# Rescale inventories and emissions for Coal PC
# Rescale inventories and emissions for Coal IGCC CCS
# Rescale inventories and emissions for Coal CHP
# Rescale inventories and emissions for Biomass IGCC
# Rescale inventories and emissions for Oil ST
# Update natural gas extraction datasets.
# Update efficiency of solar PV panels.
# Create biomass markets.
# Replace biomass inputs.
# Create region-specific power plants.
# Empty old electricity datasets
# Create high voltage markets.
# Create medium voltage markets.
# Create low voltage markets.
# Done!
# Adjust efficiency of power plants...
# Rescale inventories and emissions for Gas OC
# Rescale inventories and emissions for Biomass CHP
# Rescale inventories and emissions for Coal PC CCS
# Rescale inventories and emissions for Gas CC
# Rescale inventories and emissions for Gas CHP
# Rescale inventories and emissions for Biomass IGCC CCS
# Rescale inventories and emissions for Coal IGCC
# Rescale inventories and emissions for Gas CC CCS
# Rescale inventories and emissions for Coal PC
# Rescale inventories and emissions for Coal IGCC CCS
# Rescale inventories and emissions for Coal CHP
# Rescale inventories and emissions for Biomass IGCC
# Rescale inventories and emissions for Oil ST
# Update natural gas extraction datasets.
# Update efficiency of solar PV panels.
# Create biomass markets.
# Replace biomass inputs.
# Create region-specific power plants.
# Empty old electricity datasets
# Create high voltage markets.
# Create medium voltage markets.
# Create low voltage markets.
# Done!
# Adjust efficiency of power plants...
# Rescale inventories and emissions for Gas OC
# Rescale inventories and emissions for Biomass CHP
# Rescale inventories and emissions for Coal PC CCS
# Rescale inventories and emissions for Gas CC
# Rescale inventories and emissions for Gas CHP
# Rescale inventories and emissions for Biomass IGCC CCS
# Rescale inventories and emissions for Coal IGCC
# Rescale inventories and emissions for Gas CC CCS
# Rescale inventories and emissions for Coal PC
# Rescale inventories and emissions for Coal IGCC CCS
# Rescale inventories and emissions for Coal CHP
# Rescale inventories and emissions for Biomass IGCC
# Rescale inventories and emissions for Oil ST
# Update natural gas extraction datasets.
# Update efficiency of solar PV panels.
# Create biomass markets.
# Replace biomass inputs.
# Create region-specific power plants.
# Empty old electricity datasets
# Create high voltage markets.
# Create medium voltage markets.
# Create low voltage markets.
# Done!
# Adjust efficiency of power plants...
# Rescale inventories and emissions for Gas OC
# Rescale inventories and emissions for Biomass CHP
# Rescale inventories and emissions for Coal PC CCS
# Rescale inventories and emissions for Gas CC
# Rescale inventories and emissions for Gas CHP
# Rescale inventories and emissions for Biomass IGCC CCS
# Rescale inventories and emissions for Coal IGCC
# Rescale inventories and emissions for Gas CC CCS
# Rescale inventories and emissions for Coal PC
# Rescale inventories and emissions for Coal IGCC CCS
# Rescale inventories and emissions for Coal CHP
# Rescale inventories and emissions for Biomass IGCC
# Rescale inventories and emissions for Oil ST
# Update natural gas extraction datasets.
# Update efficiency of solar PV panels.
# Create biomass markets.
# Replace biomass inputs.
# Create region-specific power plants.
# Empty old electricity datasets
# Create high voltage markets.
# Create medium voltage markets.
# Create low voltage markets.
# Done!
# Adjust efficiency of power plants...
# Rescale inventories and emissions for Gas OC
# Rescale inventories and emissions for Biomass CHP
# Rescale inventories and emissions for Coal PC CCS
# Rescale inventories and emissions for Gas CC
# Rescale inventories and emissions for Gas CHP
# Rescale inventories and emissions for Biomass IGCC CCS
# Rescale inventories and emissions for Coal IGCC
# Rescale inventories and emissions for Gas CC CCS
# Rescale inventories and emissions for Coal PC
# Rescale inventories and emissions for Coal IGCC CCS
# Rescale inventories and emissions for Coal CHP
# Rescale inventories and emissions for Biomass IGCC
# Rescale inventories and emissions for Oil ST
# Update natural gas extraction datasets.
# Update efficiency of solar PV panels.
# Create biomass markets.
# Replace biomass inputs.
# Create region-specific power plants.
# Empty old electricity datasets
# Create high voltage markets.
# Create medium voltage markets.
# Create low voltage markets.
# Done!
# Adjust efficiency of power plants...
# Rescale inventories and emissions for Gas OC
# Rescale inventories and emissions for Biomass CHP
# Rescale inventories and emissions for Coal PC CCS
# Rescale inventories and emissions for Gas CC
# Rescale inventories and emissions for Gas CHP
# Rescale inventories and emissions for Biomass IGCC CCS
# Rescale inventories and emissions for Coal IGCC
# Rescale inventories and emissions for Gas CC CCS
# Rescale inventories and emissions for Coal PC
# Rescale inventories and emissions for Coal IGCC CCS
# Rescale inventories and emissions for Coal CHP
# Rescale inventories and emissions for Biomass IGCC
# Rescale inventories and emissions for Oil ST
# Update natural gas extraction datasets.
# Update efficiency of solar PV panels.
# Create biomass markets.
# Replace biomass inputs.
# Create region-specific power plants.
# Empty old electricity datasets
# Create high voltage markets.
# Create medium voltage markets.
# Create low voltage markets.
# Done!
# Adjust efficiency of power plants...
# Rescale inventories and emissions for Gas OC
# Rescale inventories and emissions for Biomass CHP
# Rescale inventories and emissions for Coal PC CCS
# Rescale inventories and emissions for Gas CC
# Rescale inventories and emissions for Gas CHP
# Rescale inventories and emissions for Biomass IGCC CCS
# Rescale inventories and emissions for Coal IGCC
# Rescale inventories and emissions for Gas CC CCS
# Rescale inventories and emissions for Coal PC
# Rescale inventories and emissions for Coal IGCC CCS
# Rescale inventories and emissions for Coal CHP
# Rescale inventories and emissions for Biomass IGCC
# Rescale inventories and emissions for Oil ST
#
# //////////////////////// DIRECT AIR CAPTURE ////////////////////////
# Generate region-specific direct air capture processes.
# Generate region-specific direct air capture processes.
# Generate region-specific direct air capture processes.
# Generate region-specific direct air capture processes.
# Generate region-specific direct air capture processes.
# Generate region-specific direct air capture processes.
# Generate region-specific direct air capture processes.
# Generate region-specific direct air capture processes.
# Generate region-specific direct air capture processes.
# Generate region-specific direct air capture processes.
# Generate region-specific direct air capture processes.
# Generate region-specific direct air capture processes.
# Generate region-specific direct air capture processes.
# Generate region-specific direct air capture processes.
# Generate region-specific direct air capture processes.
# Generate region-specific direct air capture processes.
# Generate region-specific direct air capture processes.
# Generate region-specific direct air capture processes.
# Generate region-specific direct air capture processes.
# Generate region-specific direct air capture processes.
# Generate region-specific direct air capture processes.
# Generate region-specific direct air capture processes.
# Generate region-specific direct air capture processes.
# Generate region-specific direct air capture processes.
# Generate region-specific direct air capture processes.
# Generate region-specific direct air capture processes.
# Generate region-specific direct air capture processes.
# Generate region-specific direct air capture processes.
# Generate region-specific direct air capture processes.
# Generate region-specific direct air capture processes.
# Generate region-specific direct air capture processes.
#
# ///////////////////////////// CEMENT //////////////////////////////
# Start integration of cement data...
# Create new clinker production datasets and delete old datasets
# Create new clinker market datasets and delete old datasets
# Create new cement market datasets
# Create new cement production datasets and adjust electricity consumption
# Done!
# Start integration of cement data...
# Create new clinker production datasets and delete old datasets
# Create new clinker market datasets and delete old datasets
# Create new cement market datasets
# Create new cement production datasets and adjust electricity consumption
# Done!
# Start integration of cement data...
# Create new clinker production datasets and delete old datasets
# Create new clinker market datasets and delete old datasets
# Create new cement market datasets
# Create new cement production datasets and adjust electricity consumption
# Done!
# Start integration of cement data...
# Create new clinker production datasets and delete old datasets
# Create new clinker market datasets and delete old datasets
# Create new cement market datasets
# Create new cement production datasets and adjust electricity consumption
# Done!
# Start integration of cement data...
# Create new clinker production datasets and delete old datasets
# Create new clinker market datasets and delete old datasets
# Create new cement market datasets
# Create new cement production datasets and adjust electricity consumption
# Done!
# Start integration of cement data...
# Create new clinker production datasets and delete old datasets
# Create new clinker market datasets and delete old datasets
# Create new cement market datasets
# Create new cement production datasets and adjust electricity consumption
# Done!
# Start integration of cement data...
# Create new clinker production datasets and delete old datasets
# Create new clinker market datasets and delete old datasets
# Create new cement market datasets
# Create new cement production datasets and adjust electricity consumption
# Done!
# Start integration of cement data...
# Create new clinker production datasets and delete old datasets
# Create new clinker market datasets and delete old datasets
# Create new cement market datasets
# Create new cement production datasets and adjust electricity consumption
# Done!
# Start integration of cement data...
# Create new clinker production datasets and delete old datasets
# Create new clinker market datasets and delete old datasets
# Create new cement market datasets
# Create new cement production datasets and adjust electricity consumption
# Done!
# Start integration of cement data...
# Create new clinker production datasets and delete old datasets
# Create new clinker market datasets and delete old datasets
# Create new cement market datasets
# Create new cement production datasets and adjust electricity consumption
# Done!
# Start integration of cement data...
# Create new clinker production datasets and delete old datasets
# Create new clinker market datasets and delete old datasets
# Create new cement market datasets
# Create new cement production datasets and adjust electricity consumption
# Done!
# Start integration of cement data...
# Create new clinker production datasets and delete old datasets
# Create new clinker market datasets and delete old datasets
# Create new cement market datasets
# Create new cement production datasets and adjust electricity consumption
# Done!
# Start integration of cement data...
# Create new clinker production datasets and delete old datasets
# Create new clinker market datasets and delete old datasets
# Create new cement market datasets
# Create new cement production datasets and adjust electricity consumption
# Done!
# Start integration of cement data...
# Create new clinker production datasets and delete old datasets
# Create new clinker market datasets and delete old datasets
# Create new cement market datasets
# Create new cement production datasets and adjust electricity consumption
# Done!
# Start integration of cement data...
# Create new clinker production datasets and delete old datasets
# Create new clinker market datasets and delete old datasets
# Create new cement market datasets
# Create new cement production datasets and adjust electricity consumption
# Done!
# Start integration of cement data...
# Create new clinker production datasets and delete old datasets
# Create new clinker market datasets and delete old datasets
# Create new cement market datasets
# Create new cement production datasets and adjust electricity consumption
# Done!
# Start integration of cement data...
# Create new clinker production datasets and delete old datasets
# Create new clinker market datasets and delete old datasets
# Create new cement market datasets
# Create new cement production datasets and adjust electricity consumption
# Done!
# Start integration of cement data...
# Create new clinker production datasets and delete old datasets
# Create new clinker market datasets and delete old datasets
# Create new cement market datasets
# Create new cement production datasets and adjust electricity consumption
# Done!
# Start integration of cement data...
# Create new clinker production datasets and delete old datasets
# Create new clinker market datasets and delete old datasets
# Create new cement market datasets
# Create new cement production datasets and adjust electricity consumption
# Done!
# Start integration of cement data...
# Create new clinker production datasets and delete old datasets
# Create new clinker market datasets and delete old datasets
# Create new cement market datasets
# Create new cement production datasets and adjust electricity consumption
# Done!
# Start integration of cement data...
# Create new clinker production datasets and delete old datasets
# Create new clinker market datasets and delete old datasets
# Create new cement market datasets
# Create new cement production datasets and adjust electricity consumption
# Done!
# Start integration of cement data...
# Create new clinker production datasets and delete old datasets
# Create new clinker market datasets and delete old datasets
# Create new cement market datasets
# Create new cement production datasets and adjust electricity consumption
# Done!
# Start integration of cement data...
# Create new clinker production datasets and delete old datasets
# Create new clinker market datasets and delete old datasets
# Create new cement market datasets
# Create new cement production datasets and adjust electricity consumption
# Done!
# Start integration of cement data...
# Create new clinker production datasets and delete old datasets
# Create new clinker market datasets and delete old datasets
# Create new cement market datasets
# Create new cement production datasets and adjust electricity consumption
# Done!
# Start integration of cement data...
# Create new clinker production datasets and delete old datasets
# Create new clinker market datasets and delete old datasets
# Create new cement market datasets
# Create new cement production datasets and adjust electricity consumption
# Done!
# Start integration of cement data...
# Create new clinker production datasets and delete old datasets
# Create new clinker market datasets and delete old datasets
# Create new cement market datasets
# Create new cement production datasets and adjust electricity consumption
# Done!
# Start integration of cement data...
# Create new clinker production datasets and delete old datasets
# Create new clinker market datasets and delete old datasets
# Create new cement market datasets
# Create new cement production datasets and adjust electricity consumption
# Done!
# Start integration of cement data...
# Create new clinker production datasets and delete old datasets
# Create new clinker market datasets and delete old datasets
# Create new cement market datasets
# Create new cement production datasets and adjust electricity consumption
# Done!
# Start integration of cement data...
# ...
# natural gas pressure reduction from high to low pressure has no fossil CO2 output.
# natural gas production has no fossil CO2 output.
# gold-silver mine operation and beneficiation has no fossil CO2 output.
# sawing and planing, azobe, air dried has no fossil CO2 output.
# sawing and planing, azobe, air dried has no fossil CO2 output.
# polyester-complexed starch biopolymer production has no fossil CO2 output.
# ilmenite - magnetite mine operation has no fossil CO2 output.
# sawing and planing, azobe, air dried has no fossil CO2 output.
# iron-nickel-chromium alloy production has no fossil CO2 output.
# transport, pipeline, onshore, long distance, natural gas has no fossil CO2 output.
# trichloromethane production has no fossil CO2 output.
# cast iron production has no fossil CO2 output.
# gold-silver mine operation and beneficiation has no fossil CO2 output.
# ilmenite - magnetite mine operation has no fossil CO2 output.
# gold-silver mine operation and beneficiation has no fossil CO2 output.
# acetylene production has no fossil CO2 output.
# cast iron production has no fossil CO2 output.
# nickel mine operation and benefication to nickel concentrate, 16% Ni has no fossil CO2 output.
# trichloromethane production has no fossil CO2 output.
# Farming and supply of wheat straw has no fossil CO2 output.
# lead acid battery, for lorry has no fossil CO2 output.
# Done!
# Generate region-specific hydrogen production pathways.
# Generate region-specific hydrogen supply chains.
# Generate region-specific biogas and syngas supply chains.
# Generate region-specific synthetic fuel supply chains.
# Generate region-specific biofuel supply chains.
# Generate new fuel markets.
# --> petrol, unleaded
# --> petrol, low-sulfur
# --> diesel, low-sulfur
# --> diesel
# --> natural gas
# --> hydrogen
# iron-nickel-chromium alloy production has no fossil CO2 output.
# acetylene production has no fossil CO2 output.
# polylactide production, granulate has no fossil CO2 output.
# transport, pipeline, offshore, long distance, natural gas has no fossil CO2 output.
# sulfite pulp production, bleached has no fossil CO2 output.
# gold-silver mine operation and beneficiation has no fossil CO2 output.
# polyester-complexed starch biopolymer production has no fossil CO2 output.
# sawing and planing, azobe, air dried has no fossil CO2 output.
# methanol production has no fossil CO2 output.
# sulfite pulp production, bleached has no fossil CO2 output.
# natural gas production has no fossil CO2 output.
# natural gas pressure reduction from high to low pressure has no fossil CO2 output.
# natural gas production has no fossil CO2 output.
# gold-silver mine operation and beneficiation has no fossil CO2 output.
# sawing and planing, azobe, air dried has no fossil CO2 output.
# sawing and planing, azobe, air dried has no fossil CO2 output.
# polyester-complexed starch biopolymer production has no fossil CO2 output.
# ilmenite - magnetite mine operation has no fossil CO2 output.
# sawing and planing, azobe, air dried has no fossil CO2 output.
# iron-nickel-chromium alloy production has no fossil CO2 output.
# transport, pipeline, onshore, long distance, natural gas has no fossil CO2 output.
# trichloromethane production has no fossil CO2 output.
# cast iron production has no fossil CO2 output.
# gold-silver mine operation and beneficiation has no fossil CO2 output.
# ilmenite - magnetite mine operation has no fossil CO2 output.
# gold-silver mine operation and beneficiation has no fossil CO2 output.
# acetylene production has no fossil CO2 output.
# cast iron production has no fossil CO2 output.
# nickel mine operation and benefication to nickel concentrate, 16% Ni has no fossil CO2 output.
# trichloromethane production has no fossil CO2 output.
# Farming and supply of wheat straw has no fossil CO2 output.
# lead acid battery, for lorry has no fossil CO2 output.
# Done!
# Generate region-specific hydrogen production pathways.
# Generate region-specific hydrogen supply chains.
# Generate region-specific biogas and syngas supply chains.
# Generate region-specific synthetic fuel supply chains.
# Generate region-specific biofuel supply chains.
# Generate new fuel markets.
# --> petrol, unleaded
# --> petrol, low-sulfur
# --> diesel, low-sulfur
# --> diesel
# --> natural gas
# --> hydrogen
# iron-nickel-chromium alloy production has no fossil CO2 output.
# acetylene production has no fossil CO2 output.
# polylactide production, granulate has no fossil CO2 output.
# transport, pipeline, offshore, long distance, natural gas has no fossil CO2 output.
# sulfite pulp production, bleached has no fossil CO2 output.
# gold-silver mine operation and beneficiation has no fossil CO2 output.
# polyester-complexed starch biopolymer production has no fossil CO2 output.
# sawing and planing, azobe, air dried has no fossil CO2 output.
# methanol production has no fossil CO2 output.
# sulfite pulp production, bleached has no fossil CO2 output.
# natural gas production has no fossil CO2 output.
# natural gas pressure reduction from high to low pressure has no fossil CO2 output.
# natural gas production has no fossil CO2 output.
# gold-silver mine operation and beneficiation has no fossil CO2 output.
# sawing and planing, azobe, air dried has no fossil CO2 output.
# sawing and planing, azobe, air dried has no fossil CO2 output.
# polyester-complexed starch biopolymer production has no fossil CO2 output.
# ilmenite - magnetite mine operation has no fossil CO2 output.
# sawing and planing, azobe, air dried has no fossil CO2 output.
# iron-nickel-chromium alloy production has no fossil CO2 output.
# transport, pipeline, onshore, long distance, natural gas has no fossil CO2 output.
# trichloromethane production has no fossil CO2 output.
# cast iron production has no fossil CO2 output.
# gold-silver mine operation and beneficiation has no fossil CO2 output.
# ilmenite - magnetite mine operation has no fossil CO2 output.
# gold-silver mine operation and beneficiation has no fossil CO2 output.
# acetylene production has no fossil CO2 output.
# cast iron production has no fossil CO2 output.
# nickel mine operation and benefication to nickel concentrate, 16% Ni has no fossil CO2 output.
# trichloromethane production has no fossil CO2 output.
# Farming and supply of wheat straw has no fossil CO2 output.
# lead acid battery, for lorry has no fossil CO2 output.
# Done!
# Generate region-specific hydrogen production pathways.
# Generate region-specific hydrogen supply chains.
# Generate region-specific biogas and syngas supply chains.
# Generate region-specific synthetic fuel supply chains.
# Generate region-specific biofuel supply chains.
# Generate new fuel markets.
# --> petrol, unleaded
# --> petrol, low-sulfur
# --> diesel, low-sulfur
# --> diesel
# --> natural gas
# --> hydrogen
# iron-nickel-chromium alloy production has no fossil CO2 output.
# acetylene production has no fossil CO2 output.
# polylactide production, granulate has no fossil CO2 output.
# transport, pipeline, offshore, long distance, natural gas has no fossil CO2 output.
# sulfite pulp production, bleached has no fossil CO2 output.
# gold-silver mine operation and beneficiation has no fossil CO2 output.
# polyester-complexed starch biopolymer production has no fossil CO2 output.
# sawing and planing, azobe, air dried has no fossil CO2 output.
# methanol production has no fossil CO2 output.
# sulfite pulp production, bleached has no fossil CO2 output.
# natural gas production has no fossil CO2 output.
# natural gas pressure reduction from high to low pressure has no fossil CO2 output.
# natural gas production has no fossil CO2 output.
# gold-silver mine operation and beneficiation has no fossil CO2 output.
# sawing and planing, azobe, air dried has no fossil CO2 output.
# sawing and planing, azobe, air dried has no fossil CO2 output.
# polyester-complexed starch biopolymer production has no fossil CO2 output.
# ilmenite - magnetite mine operation has no fossil CO2 output.
# sawing and planing, azobe, air dried has no fossil CO2 output.
# iron-nickel-chromium alloy production has no fossil CO2 output.
# transport, pipeline, onshore, long distance, natural gas has no fossil CO2 output.
# trichloromethane production has no fossil CO2 output.
# cast iron production has no fossil CO2 output.
# gold-silver mine operation and beneficiation has no fossil CO2 output.
# ilmenite - magnetite mine operation has no fossil CO2 output.
# gold-silver mine operation and beneficiation has no fossil CO2 output.
# acetylene production has no fossil CO2 output.
# cast iron production has no fossil CO2 output.
# nickel mine operation and benefication to nickel concentrate, 16% Ni has no fossil CO2 output.
# trichloromethane production has no fossil CO2 output.
# Farming and supply of wheat straw has no fossil CO2 output.
# lead acid battery, for lorry has no fossil CO2 output.
# Done!
# Generate region-specific hydrogen production pathways.
# Generate region-specific hydrogen supply chains.
# Generate region-specific biogas and syngas supply chains.
# Generate region-specific synthetic fuel supply chains.
# Generate region-specific biofuel supply chains.
# Generate new fuel markets.
# --> petrol, unleaded
# --> petrol, low-sulfur
# --> diesel, low-sulfur
# --> diesel
# --> natural gas
# --> hydrogen
# iron-nickel-chromium alloy production has no fossil CO2 output.
# acetylene production has no fossil CO2 output.
# polylactide production, granulate has no fossil CO2 output.
# transport, pipeline, offshore, long distance, natural gas has no fossil CO2 output.
# sulfite pulp production, bleached has no fossil CO2 output.
# gold-silver mine operation and beneficiation has no fossil CO2 output.
# polyester-complexed starch biopolymer production has no fossil CO2 output.
# sawing and planing, azobe, air dried has no fossil CO2 output.
# methanol production has no fossil CO2 output.
# sulfite pulp production, bleached has no fossil CO2 output.
# natural gas production has no fossil CO2 output.
# natural gas pressure reduction from high to low pressure has no fossil CO2 output.
# natural gas production has no fossil CO2 output.
# gold-silver mine operation and beneficiation has no fossil CO2 output.
# sawing and planing, azobe, air dried has no fossil CO2 output.
# sawing and planing, azobe, air dried has no fossil CO2 output.
# polyester-complexed starch biopolymer production has no fossil CO2 output.
# ilmenite - magnetite mine operation has no fossil CO2 output.
# sawing and planing, azobe, air dried has no fossil CO2 output.
# iron-nickel-chromium alloy production has no fossil CO2 output.
# transport, pipeline, onshore, long distance, natural gas has no fossil CO2 output.
# trichloromethane production has no fossil CO2 output.
# cast iron production has no fossil CO2 output.
# gold-silver mine operation and beneficiation has no fossil CO2 output.
# ilmenite - magnetite mine operation has no fossil CO2 output.
# gold-silver mine operation and beneficiation has no fossil CO2 output.
# acetylene production has no fossil CO2 output.
# cast iron production has no fossil CO2 output.
# nickel mine operation and benefication to nickel concentrate, 16% Ni has no fossil CO2 output.
# trichloromethane production has no fossil CO2 output.
# Farming and supply of wheat straw has no fossil CO2 output.
# lead acid battery, for lorry has no fossil CO2 output.
# Done!
# Generate region-specific hydrogen production pathways.
# Generate region-specific hydrogen supply chains.
# Generate region-specific biogas and syngas supply chains.
# Generate region-specific synthetic fuel supply chains.
# Generate region-specific biofuel supply chains.
# Generate new fuel markets.
# --> petrol, unleaded
# --> petrol, low-sulfur
# --> diesel, low-sulfur
# --> diesel
# --> natural gas
# --> hydrogen
# iron-nickel-chromium alloy production has no fossil CO2 output.
# acetylene production has no fossil CO2 output.
# polylactide production, granulate has no fossil CO2 output.
# transport, pipeline, offshore, long distance, natural gas has no fossil CO2 output.
# sulfite pulp production, bleached has no fossil CO2 output.
# gold-silver mine operation and beneficiation has no fossil CO2 output.
# polyester-complexed starch biopolymer production has no fossil CO2 output.
# sawing and planing, azobe, air dried has no fossil CO2 output.
# methanol production has no fossil CO2 output.
# sulfite pulp production, bleached has no fossil CO2 output.
# natural gas production has no fossil CO2 output.
# natural gas pressure reduction from high to low pressure has no fossil CO2 output.
# natural gas production has no fossil CO2 output.
# gold-silver mine operation and beneficiation has no fossil CO2 output.
# sawing and planing, azobe, air dried has no fossil CO2 output.
# sawing and planing, azobe, air dried has no fossil CO2 output.
# polyester-complexed starch biopolymer production has no fossil CO2 output.
# ilmenite - magnetite mine operation has no fossil CO2 output.
# sawing and planing, azobe, air dried has no fossil CO2 output.
# iron-nickel-chromium alloy production has no fossil CO2 output.
# transport, pipeline, onshore, long distance, natural gas has no fossil CO2 output.
# trichloromethane production has no fossil CO2 output.
# cast iron production has no fossil CO2 output.
# gold-silver mine operation and beneficiation has no fossil CO2 output.
# ilmenite - magnetite mine operation has no fossil CO2 output.
# gold-silver mine operation and beneficiation has no fossil CO2 output.
# acetylene production has no fossil CO2 output.
# cast iron production has no fossil CO2 output.
# nickel mine operation and benefication to nickel concentrate, 16% Ni has no fossil CO2 output.
# trichloromethane production has no fossil CO2 output.
# Farming and supply of wheat straw has no fossil CO2 output.
# lead acid battery, for lorry has no fossil CO2 output.
# Done!
#
# /////////////////////////// EMISSIONS //////////////////////////////
# Integrating GAINS EU emission factors.
# Integrating GAINS IAM emission factors.
# Integrating GAINS EU emission factors.
# Integrating GAINS IAM emission factors.
# Integrating GAINS EU emission factors.
# Integrating GAINS IAM emission factors.
# Integrating GAINS EU emission factors.
# Integrating GAINS IAM emission factors.
# Integrating GAINS EU emission factors.
# Integrating GAINS IAM emission factors.
# Integrating GAINS EU emission factors.
# Integrating GAINS IAM emission factors.
# Integrating GAINS EU emission factors.
# Integrating GAINS IAM emission factors.
# Integrating GAINS EU emission factors.
# Integrating GAINS IAM emission factors.
# Integrating GAINS EU emission factors.
# Integrating GAINS IAM emission factors.
# Integrating GAINS EU emission factors.
# Integrating GAINS IAM emission factors.
# Integrating GAINS EU emission factors.
# Integrating GAINS IAM emission factors.
# Integrating GAINS EU emission factors.
# Integrating GAINS IAM emission factors.
# Integrating GAINS EU emission factors.
# Integrating GAINS IAM emission factors.
# Integrating GAINS EU emission factors.
# Integrating GAINS IAM emission factors.
# Integrating GAINS EU emission factors.
# Integrating GAINS IAM emission factors.
# Integrating GAINS EU emission factors.
# Integrating GAINS IAM emission factors.
# Integrating GAINS EU emission factors.
# Integrating GAINS IAM emission factors.
# Integrating GAINS EU emission factors.
# Integrating GAINS IAM emission factors.
# Integrating GAINS EU emission factors.
# Integrating GAINS IAM emission factors.
# Integrating GAINS EU emission factors.
# Integrating GAINS IAM emission factors.
# Integrating GAINS EU emission factors.
# Integrating GAINS IAM emission factors.
# Integrating GAINS EU emission factors.
# Integrating GAINS IAM emission factors.
# Integrating GAINS EU emission factors.
# Integrating GAINS IAM emission factors.
# Integrating GAINS EU emission factors.
# Integrating GAINS IAM emission factors.
# Integrating GAINS EU emission factors.
# Integrating GAINS IAM emission factors.
# Integrating GAINS EU emission factors.
# Integrating GAINS IAM emission factors.
# Integrating GAINS EU emission factors.
# Integrating GAINS IAM emission factors.
# Integrating GAINS EU emission factors.
# Integrating GAINS IAM emission factors.
# Integrating GAINS EU emission factors.
# Integrating GAINS IAM emission factors.
# Integrating GAINS EU emission factors.
# Integrating GAINS IAM emission factors.
# Integrating GAINS EU emission factors.
# Integrating GAINS IAM emission factors.

# %%
newDataBase.write_db_to_brightway(name = databaseNames)
# Out:
# Write new database(s) to Brightway2.
# Prepare database 1.
# - check for duplicates...
# One or multiple duplicates detected. Removing them...
# - check for values format...
# - relinking exchanges...
# Done!
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 07/03/2023 23:44:29
#   Finished: 07/03/2023 23:45:08
#   Total time elapsed: 00:00:38
#   CPU %: 88.40
#   Memory %: 20.63
# Created database: ecoinvent 3.8 cutoff image SSP2-Base 2020
# Prepare database 2.
# - check for duplicates...
# One or multiple duplicates detected. Removing them...
# - check for values format...
# - relinking exchanges...
# Done!
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 07/03/2023 23:46:32
#   Finished: 07/03/2023 23:47:09
#   Total time elapsed: 00:00:36
#   CPU %: 91.00
#   Memory %: 22.48
# Created database: ecoinvent 3.8 cutoff image SSP2-Base 2030
# Prepare database 3.
# - check for duplicates...
# One or multiple duplicates detected. Removing them...
# - check for values format...
# - relinking exchanges...
# Done!
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 07/03/2023 23:48:37
#   Finished: 07/03/2023 23:49:14
#   Total time elapsed: 00:00:36
#   CPU %: 90.70
#   Memory %: 21.19
# Created database: ecoinvent 3.8 cutoff image SSP2-Base 2040
# Prepare database 4.
# - check for duplicates...
# One or multiple duplicates detected. Removing them...
# - check for values format...
# - relinking exchanges...
# Done!
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 07/03/2023 23:50:48
#   Finished: 07/03/2023 23:51:24
#   Total time elapsed: 00:00:36
#   CPU %: 90.10
#   Memory %: 22.81
# Created database: ecoinvent 3.8 cutoff image SSP2-Base 2050
# Prepare database 5.
# - check for duplicates...
# One or multiple duplicates detected. Removing them...
# - check for values format...
# - relinking exchanges...
# Done!
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 07/03/2023 23:53:07
#   Finished: 07/03/2023 23:53:45
#   Total time elapsed: 00:00:37
#   CPU %: 88.90
#   Memory %: 22.30
# Created database: ecoinvent 3.8 cutoff image SSP2-RCP19 2030
# Prepare database 6.
# - check for duplicates...
# One or multiple duplicates detected. Removing them...
# - check for values format...
# - relinking exchanges...
# Done!
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 07/03/2023 23:55:32
#   Finished: 07/03/2023 23:56:10
#   Total time elapsed: 00:00:38
#   CPU %: 89.00
#   Memory %: 22.52
# Created database: ecoinvent 3.8 cutoff image SSP2-RCP19 2040
# Prepare database 7.
# - check for duplicates...
# One or multiple duplicates detected. Removing them...
# - check for values format...
# - relinking exchanges...
# Done!
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 07/03/2023 23:58:06
#   Finished: 07/03/2023 23:58:44
#   Total time elapsed: 00:00:37
#   CPU %: 89.20
#   Memory %: 22.81
# Created database: ecoinvent 3.8 cutoff image SSP2-RCP19 2050
# Prepare database 8.
# - check for duplicates...
# One or multiple duplicates detected. Removing them...
# - check for values format...
# - relinking exchanges...
# Done!
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 07/04/2023 00:00:47
#   Finished: 07/04/2023 00:01:25
#   Total time elapsed: 00:00:38
#   CPU %: 89.00
#   Memory %: 21.69
# Created database: ecoinvent 3.8 cutoff image SSP2-RCP26 2030
# Prepare database 9.
# - check for duplicates...
# One or multiple duplicates detected. Removing them...
# - check for values format...
# - relinking exchanges...
# Done!
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 07/04/2023 00:03:35
#   Finished: 07/04/2023 00:04:12
#   Total time elapsed: 00:00:37
#   CPU %: 89.30
#   Memory %: 22.95
# Created database: ecoinvent 3.8 cutoff image SSP2-RCP26 2040
# Prepare database 10.
# - check for duplicates...
# One or multiple duplicates detected. Removing them...
# - check for values format...
# - relinking exchanges...
# Done!
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 07/04/2023 00:06:30
#   Finished: 07/04/2023 00:07:09
#   Total time elapsed: 00:00:38
#   CPU %: 88.80
#   Memory %: 24.00
# Created database: ecoinvent 3.8 cutoff image SSP2-RCP26 2050
# Prepare database 11.
# - check for duplicates...
# One or multiple duplicates detected. Removing them...
# - check for values format...
# - relinking exchanges...
# Done!
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 07/04/2023 00:09:28
#   Finished: 07/04/2023 00:10:05
#   Total time elapsed: 00:00:37
#   CPU %: 88.70
#   Memory %: 22.46
# Created database: ecoinvent 3.8 cutoff remind SSP1-PkBudg1150 2030
# Prepare database 12.
# - check for duplicates...
# One or multiple duplicates detected. Removing them...
# - check for values format...
# - relinking exchanges...
# Done!
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 07/04/2023 00:12:25
#   Finished: 07/04/2023 00:13:02
#   Total time elapsed: 00:00:37
#   CPU %: 89.00
#   Memory %: 22.15
# Created database: ecoinvent 3.8 cutoff remind SSP1-PkBudg1150 2040
# Prepare database 13.
# - check for duplicates...
# One or multiple duplicates detected. Removing them...
# - check for values format...
# - relinking exchanges...
# Done!
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 07/04/2023 00:15:31
#   Finished: 07/04/2023 00:16:09
#   Total time elapsed: 00:00:38
#   CPU %: 89.00
#   Memory %: 18.63
# Created database: ecoinvent 3.8 cutoff remind SSP1-PkBudg1150 2050
# Prepare database 14.
# - check for duplicates...
# One or multiple duplicates detected. Removing them...
# - check for values format...
# - relinking exchanges...
# Done!
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 07/04/2023 00:18:45
#   Finished: 07/04/2023 00:19:22
#   Total time elapsed: 00:00:37
#   CPU %: 89.10
#   Memory %: 23.29
# Created database: ecoinvent 3.8 cutoff remind SSP1-PkBudg500 2030
# Prepare database 15.
# - check for duplicates...
# One or multiple duplicates detected. Removing them...
# - check for values format...
# - relinking exchanges...
# Done!
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 07/04/2023 00:22:04
#   Finished: 07/04/2023 00:22:43
#   Total time elapsed: 00:00:39
#   CPU %: 88.00
#   Memory %: 20.22
# Created database: ecoinvent 3.8 cutoff remind SSP1-PkBudg500 2040
# Prepare database 16.
# - check for duplicates...
# One or multiple duplicates detected. Removing them...
# - check for values format...
# - relinking exchanges...
# Done!
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 07/04/2023 00:25:33
#   Finished: 07/04/2023 00:26:10
#   Total time elapsed: 00:00:37
#   CPU %: 89.40
#   Memory %: 23.55
# Created database: ecoinvent 3.8 cutoff remind SSP1-PkBudg500 2050
# Prepare database 17.
# - check for duplicates...
# One or multiple duplicates detected. Removing them...
# - check for values format...
# - relinking exchanges...
# Done!
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 07/04/2023 00:29:07
#   Finished: 07/04/2023 00:29:45
#   Total time elapsed: 00:00:37
#   CPU %: 89.20
#   Memory %: 22.57
# Created database: ecoinvent 3.8 cutoff remind SSP2-Base 2030
# Prepare database 18.
# - check for duplicates...
# One or multiple duplicates detected. Removing them...
# - check for values format...
# - relinking exchanges...
# Done!
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 07/04/2023 00:32:47
#   Finished: 07/04/2023 00:33:25
#   Total time elapsed: 00:00:38
#   CPU %: 89.00
#   Memory %: 21.48
# Created database: ecoinvent 3.8 cutoff remind SSP2-Base 2040
# Prepare database 19.
# - check for duplicates...
# One or multiple duplicates detected. Removing them...
# - check for values format...
# - relinking exchanges...
# Done!
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 07/04/2023 00:36:36
#   Finished: 07/04/2023 00:37:14
#   Total time elapsed: 00:00:37
#   CPU %: 89.20
#   Memory %: 24.64
# Created database: ecoinvent 3.8 cutoff remind SSP2-Base 2050
# Prepare database 20.
# - check for duplicates...
# One or multiple duplicates detected. Removing them...
# - check for values format...
# - relinking exchanges...
# Done!
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 07/04/2023 00:40:32
#   Finished: 07/04/2023 00:41:00
#   Total time elapsed: 00:00:27
#   CPU %: 90.60
#   Memory %: 22.73
# Created database: ecoinvent 3.8 cutoff remind SSP2-PkBudg1150 2030
# Prepare database 21.
# - check for duplicates...
# One or multiple duplicates detected. Removing them...
# - check for values format...
# - relinking exchanges...
# Done!
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 07/04/2023 00:44:40
#   Finished: 07/04/2023 00:45:11
#   Total time elapsed: 00:00:31
#   CPU %: 89.30
#   Memory %: 19.69
# Created database: ecoinvent 3.8 cutoff remind SSP2-PkBudg1150 2040
# Prepare database 22.
# - check for duplicates...
# One or multiple duplicates detected. Removing them...
# - check for values format...
# - relinking exchanges...
# Done!
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 07/04/2023 00:48:54
#   Finished: 07/04/2023 00:49:23
#   Total time elapsed: 00:00:28
#   CPU %: 91.10
#   Memory %: 22.71
# Created database: ecoinvent 3.8 cutoff remind SSP2-PkBudg1150 2050
# Prepare database 23.
# - check for duplicates...
# One or multiple duplicates detected. Removing them...
# - check for values format...
# - relinking exchanges...
# Done!
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 07/04/2023 00:53:12
#   Finished: 07/04/2023 00:53:40
#   Total time elapsed: 00:00:27
#   CPU %: 91.30
#   Memory %: 24.72
# Created database: ecoinvent 3.8 cutoff remind SSP2-PkBudg500 2030
# Prepare database 24.
# - check for duplicates...
# One or multiple duplicates detected. Removing them...
# - check for values format...
# - relinking exchanges...
# Done!
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 07/04/2023 00:57:33
#   Finished: 07/04/2023 00:58:03
#   Total time elapsed: 00:00:29
#   CPU %: 89.60
#   Memory %: 22.69
# Created database: ecoinvent 3.8 cutoff remind SSP2-PkBudg500 2040
# Prepare database 25.
# - check for duplicates...
# One or multiple duplicates detected. Removing them...
# - check for values format...
# - relinking exchanges...
# Done!
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 07/04/2023 01:02:06
#   Finished: 07/04/2023 01:02:36
#   Total time elapsed: 00:00:30
#   CPU %: 89.40
#   Memory %: 22.38
# Created database: ecoinvent 3.8 cutoff remind SSP2-PkBudg500 2050
# Prepare database 26.
# - check for duplicates...
# One or multiple duplicates detected. Removing them...
# - check for values format...
# - relinking exchanges...
# Done!
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 07/04/2023 01:06:34
#   Finished: 07/04/2023 01:07:14
#   Total time elapsed: 00:00:39
#   CPU %: 88.60
#   Memory %: 23.17
# Created database: ecoinvent 3.8 cutoff remind SSP5-PkBudg1150 2030
# Prepare database 27.
# - check for duplicates...
# One or multiple duplicates detected. Removing them...
# - check for values format...
# - relinking exchanges...
# Done!
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 07/04/2023 01:11:25
#   Finished: 07/04/2023 01:12:05
#   Total time elapsed: 00:00:40
#   CPU %: 88.30
#   Memory %: 21.60
# Created database: ecoinvent 3.8 cutoff remind SSP5-PkBudg1150 2040
# Prepare database 28.
# - check for duplicates...
# One or multiple duplicates detected. Removing them...
# - check for values format...
# - relinking exchanges...
# Done!
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 07/04/2023 01:16:30
#   Finished: 07/04/2023 01:17:09
#   Total time elapsed: 00:00:38
#   CPU %: 88.90
#   Memory %: 24.31
# Created database: ecoinvent 3.8 cutoff remind SSP5-PkBudg1150 2050
# Prepare database 29.
# - check for duplicates...
# One or multiple duplicates detected. Removing them...
# - check for values format...
# - relinking exchanges...
# Done!
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 07/04/2023 01:21:37
#   Finished: 07/04/2023 01:22:16
#   Total time elapsed: 00:00:39
#   CPU %: 88.70
#   Memory %: 23.39
# Created database: ecoinvent 3.8 cutoff remind SSP5-PkBudg500 2030
# Prepare database 30.
# - check for duplicates...
# One or multiple duplicates detected. Removing them...
# - check for values format...
# - relinking exchanges...
# Done!
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 07/04/2023 01:26:43
#   Finished: 07/04/2023 01:27:22
#   Total time elapsed: 00:00:39
#   CPU %: 88.80
#   Memory %: 23.45
# Created database: ecoinvent 3.8 cutoff remind SSP5-PkBudg500 2040
# Prepare database 31.
# - check for duplicates...
# One or multiple duplicates detected. Removing them...
# - check for values format...
# - relinking exchanges...
# Done!
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 07/04/2023 01:32:08
#   Finished: 07/04/2023 01:32:48
#   Total time elapsed: 00:00:40
#   CPU %: 88.60
#   Memory %: 23.94
# Created database: ecoinvent 3.8 cutoff remind SSP5-PkBudg500 2050
# Generate scenario report.
# Report saved under /Users/abhinabera/Desktop/High-Throughput-LCA/Code/export/scenario_report.
# Generate change report.
# Report saved under /Users/abhinabera/Desktop/High-Throughput-LCA/Code.

# %%
endTime = time.time()

# %%
elapsedTime = endTime - startTime
print(f'Elapsed time: {elapsedTime / 60:.2f} minutes')
# Out:
# Elapsed time: 236.95 minutes

# %%
list(bw.databases)
# Out:
# ['biosphere3',
#  'ecoinvent 3.8 cutoff',
#  'ecoinvent 3.8 cutoff image SSP2-Base 2020',
#  'ecoinvent 3.8 cutoff image SSP2-Base 2030',
#  'ecoinvent 3.8 cutoff image SSP2-Base 2040',
#  'ecoinvent 3.8 cutoff image SSP2-Base 2050',
#  'ecoinvent 3.8 cutoff image SSP2-RCP19 2030',
#  'ecoinvent 3.8 cutoff image SSP2-RCP19 2040',
#  'ecoinvent 3.8 cutoff image SSP2-RCP19 2050',
#  'ecoinvent 3.8 cutoff image SSP2-RCP26 2030',
#  'ecoinvent 3.8 cutoff image SSP2-RCP26 2040',
#  'ecoinvent 3.8 cutoff image SSP2-RCP26 2050',
#  'ecoinvent 3.8 cutoff remind SSP1-PkBudg1150 2030',
#  'ecoinvent 3.8 cutoff remind SSP1-PkBudg1150 2040',
#  'ecoinvent 3.8 cutoff remind SSP1-PkBudg1150 2050',
#  'ecoinvent 3.8 cutoff remind SSP1-PkBudg500 2030',
#  'ecoinvent 3.8 cutoff remind SSP1-PkBudg500 2040',
#  'ecoinvent 3.8 cutoff remind SSP1-PkBudg500 2050',
#  'ecoinvent 3.8 cutoff remind SSP2-Base 2030',
#  'ecoinvent 3.8 cutoff remind SSP2-Base 2040',
#  'ecoinvent 3.8 cutoff remind SSP2-Base 2050',
#  'ecoinvent 3.8 cutoff remind SSP2-PkBudg1150 2030',
#  'ecoinvent 3.8 cutoff remind SSP2-PkBudg1150 2040',
#  'ecoinvent 3.8 cutoff remind SSP2-PkBudg1150 2050',
#  'ecoinvent 3.8 cutoff remind SSP2-PkBudg500 2030',
#  'ecoinvent 3.8 cutoff remind SSP2-PkBudg500 2040',
#  'ecoinvent 3.8 cutoff remind SSP2-PkBudg500 2050',
#  'ecoinvent 3.8 cutoff remind SSP5-PkBudg1150 2030',
#  'ecoinvent 3.8 cutoff remind SSP5-PkBudg1150 2040',
#  'ecoinvent 3.8 cutoff remind SSP5-PkBudg1150 2050',
#  'ecoinvent 3.8 cutoff remind SSP5-PkBudg500 2030',
#  'ecoinvent 3.8 cutoff remind SSP5-PkBudg500 2040',
#  'ecoinvent 3.8 cutoff remind SSP5-PkBudg500 2050']
